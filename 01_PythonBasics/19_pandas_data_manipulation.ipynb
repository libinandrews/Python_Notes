# %% [markdown]
# ## What is Pandas?
#
# - **Pandas** is a powerful Python library used for **data analysis and data manipulation**.
# - It is built on top of **NumPy**.
# - It provides easy tools to work with **structured data (tables)**.
# - Pandas is widely used in:
#   - Data Science
#   - Machine Learning
#   - Finance
#   - Data Engineering
#   - Research
#
# Main features:
#
# - Easy data loading (CSV, Excel, JSON, SQL)
# - Data cleaning and transformation
# - Data aggregation and analysis
# - Time series support
# - Integration with visualization libraries

# %% [markdown]
# ```bash
# !pip install pandas
# ```

# %% [markdown]
# ---
#
# # Core Data Structures
#
# Pandas provides two main data structures.
#
# ## 1️⃣ Series
#
# - A **Series** is a one-dimensional labeled array.
# - Similar to a column in a table.

# %%
import pandas as pd

data = pd.Series([10,20,30,40])

print(data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# ## 2️⃣ DataFrame
#
# * A **DataFrame** is a two-dimensional table.
# * Similar to an **Excel sheet or SQL table**.
# * Rows → records
# * Columns → variables

# %%
data = {
    "Name": ["Alice","Bob","Charlie"],
    "Age": [25,30,35],
    "City": ["NY","LA","Chicago"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#       Name  Age     City
# 0    Alice   25       NY
# 1      Bob   30       LA
# 2  Charlie   35  Chicago

# %% [markdown]
# ---
#
# # Creating DataFrames

# %%
# From Dictionary
df = pd.DataFrame({
    "A":[1,2,3],
    "B":[4,5,6]
})
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
# From List
data = [
    ["Alice",25],
    ["Bob",30]
]

df = pd.DataFrame(data, columns=["Name","Age"])
df
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %% [markdown]
# # Reading Data (Very Common)
# Pandas supports many file formats.

# %%
file_name = r"db\demo_student_marksheet_dataset.csv"

# %%
df = pd.read_csv(file_name)

# %%
# Excel, json etc

# %%
# pd.read

# %% [markdown]
# # Viewing Data

# %%
# First rows
df.head()
# Out:
#    Student_ID            Name  Age             Address  Malayalam  English  \
# 0      300657           Dasan   21        Nadodikkattu         68       85
# 1      300658         Vijayan   16        Nadodikkattu         94       60
# 2      300659         Ramanan   18       Punjabi House         69       75
# 3      300660   Mannar Mathai   20  Ramji Rao Speaking         93       75
# 4      300661  Gopalakrishnan   15           Godfather         88       75
#
#    Hindi  Social_Science  Physics  Chemistry  Biology  Mathematics  \
# 0     64              59       82         68       77           70
# 1     53              77       56         71       55           88
# 2     73              40       82         71       84           90
# 3     89              85       72         69       62           57
# 4     67              54       60         64       73           99
#
#    Information_Technology  Total  Percentage
# 0                      79    652   72.444444
# ...

# %%
# Last rows
df.tail()
# Out:
#     Student_ID              Name  Age                  Address  Malayalam  \
# 74      300731            Soumya   21  Maheshinte Prathikaaram         62
# 75      300732            Kannan   21            Minnal Murali         54
# 76      300733           Josemon   21            Minnal Murali         80
# 77      300734             Shibu   19            Minnal Murali         43
# 78      300735  Dashamoolam Damu   21            Chattambinadu         40
#
#     English  Hindi  Social_Science  Physics  Chemistry  Biology  Mathematics  \
# 74       80     92              98       84         88       51           74
# 75       59     75              71       74         58       74           81
# 76       69     92              55       88         61       64           56
# 77       43     49              42       58         49       60           45
# 78       57     82              54       52         72       88           58
#
#     Information_Technology  Total  Percentage
# ...

# %%
# Data summary
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Student_ID              79 non-null     int64
#  1   Name                    79 non-null     str
#  2   Age                     79 non-null     int64
#  3   Address                 79 non-null     str
#  4   Malayalam               79 non-null     int64
#  5   English                 79 non-null     int64
#  6   Hindi                   79 non-null     int64
#  7   Social_Science          79 non-null     int64
#  8   Physics                 79 non-null     int64
#  9   Chemistry               79 non-null     int64
#  10  Biology                 79 non-null     int64
#  11  Mathematics             79 non-null     int64
#  12  Information_Technology  79 non-null     int64
#  13  Total                   79 non-null     int64
#  14  Percentage              79 non-null     float64
# ...

# %%
# Statistics
df.describe()
# Out:
#           Student_ID        Age  Malayalam    English      Hindi  \
# count      79.000000  79.000000  79.000000  79.000000  79.000000
# mean   300696.000000  18.392405  66.670886  63.012658  67.126582
# std        22.949219   2.174548  16.137805  15.205847  16.587273
# min    300657.000000  15.000000  40.000000  40.000000  40.000000
# 25%    300676.500000  17.000000  53.500000  52.500000  53.000000
# 50%    300696.000000  18.000000  66.000000  59.000000  65.000000
# 75%    300715.500000  20.000000  80.500000  75.000000  82.000000
# max    300735.000000  22.000000  94.000000  95.000000  98.000000
#
#        Social_Science     Physics  Chemistry     Biology  Mathematics  \
# count       79.000000   79.000000  79.000000   79.000000    79.000000
# mean        65.506329   65.443038  71.025316   64.253165    64.898734
# std         16.531922   16.537252  14.730027   14.578231    17.363825
# min         40.000000   40.000000  40.000000   40.000000    40.000000
# ...

# %% [markdown]
# # Selecting Data

# %%
# Select column
df["Name"]
# Out:
# 0                Dasan
# 1              Vijayan
# 2              Ramanan
# 3        Mannar Mathai
# 4       Gopalakrishnan
#             ...
# 74              Soumya
# 75              Kannan
# 76             Josemon
# 77               Shibu
# 78    Dashamoolam Damu
# Name: Name, Length: 79, dtype: str

# %%
# Multiple columns
df[["Name","Age"]]
# Out:
#                 Name  Age
# 0              Dasan   21
# 1            Vijayan   16
# 2            Ramanan   18
# 3      Mannar Mathai   20
# 4     Gopalakrishnan   15
# ..               ...  ...
# 74            Soumya   21
# 75            Kannan   21
# 76           Josemon   21
# 77             Shibu   19
# 78  Dashamoolam Damu   21
#
# [79 rows x 2 columns]

# %%
# Select rows
df.iloc[0]
# Out:
# Student_ID                      300657
# Name                             Dasan
# Age                                 21
# Address                   Nadodikkattu
# Malayalam                           68
# English                             85
# Hindi                               64
# Social_Science                      59
# Physics                             82
# Chemistry                           68
# Biology                             77
# Mathematics                         70
# Information_Technology              79
# Total                              652
# Percentage                   72.444444
# Name: 0, dtype: object

# %%
# Label based selection
df.loc[0]
# Out:
# Student_ID                      300657
# Name                             Dasan
# Age                                 21
# Address                   Nadodikkattu
# Malayalam                           68
# English                             85
# Hindi                               64
# Social_Science                      59
# Physics                             82
# Chemistry                           68
# Biology                             77
# Mathematics                         70
# Information_Technology              79
# Total                              652
# Percentage                   72.444444
# Name: 0, dtype: object

# %%
# Filtering Data
df[df["Malayalam"]< 100]
# Out:
#     Student_ID              Name  Age                  Address  Malayalam  \
# 0       300657             Dasan   21             Nadodikkattu         68
# 1       300658           Vijayan   16             Nadodikkattu         94
# 2       300659           Ramanan   18            Punjabi House         69
# 3       300660     Mannar Mathai   20       Ramji Rao Speaking         93
# 4       300661    Gopalakrishnan   15                Godfather         88
# ..         ...               ...  ...                      ...        ...
# 74      300731            Soumya   21  Maheshinte Prathikaaram         62
# 75      300732            Kannan   21            Minnal Murali         54
# 76      300733           Josemon   21            Minnal Murali         80
# 77      300734             Shibu   19            Minnal Murali         43
# 78      300735  Dashamoolam Damu   21            Chattambinadu         40
#
#     English  Hindi  Social_Science  Physics  Chemistry  Biology  Mathematics  \
# ...

# %%
df["Malayalam"] .describe()
# Out:
# count    79.000000
# mean     66.670886
# std      16.137805
# min      40.000000
# 25%      53.500000
# 50%      66.000000
# 75%      80.500000
# max      94.000000
# Name: Malayalam, dtype: float64

# %%
# Multiple conditions
df[(df["Malayalam"] > 90) & (df["Hindi"] < 50)]
# Out:
#     Student_ID                Name  Age    Address  Malayalam  English  Hindi  \
# 12      300669  Thorappan Kochunni   18  CID Moosa         93       54     44
#
#     Social_Science  Physics  Chemistry  Biology  Mathematics  \
# 12              44       98         67       74           60
#
#     Information_Technology  Total  Percentage
# 12                      52    586   65.111111

# %%
# Adding and Modifying Columns
df["Average_Mark"] = df["Total"] / 9

df.head()
# Out:
#    Student_ID            Name  Age             Address  Malayalam  English  \
# 0      300657           Dasan   21        Nadodikkattu         68       85
# 1      300658         Vijayan   16        Nadodikkattu         94       60
# 2      300659         Ramanan   18       Punjabi House         69       75
# 3      300660   Mannar Mathai   20  Ramji Rao Speaking         93       75
# 4      300661  Gopalakrishnan   15           Godfather         88       75
#
#    Hindi  Social_Science  Physics  Chemistry  Biology  Mathematics  \
# 0     64              59       82         68       77           70
# 1     53              77       56         71       55           88
# 2     73              40       82         71       84           90
# 3     89              85       72         69       62           57
# 4     67              54       60         64       73           99
#
#    Information_Technology  Total  Percentage  Average_Mark
# ...

# %% [markdown]
# # Removing Data

# %%
# Drop column
df.drop(columns=["Average_Mark"])
# Out:
#     Student_ID              Name  Age                  Address  Malayalam  \
# 0       300657             Dasan   21             Nadodikkattu         68
# 1       300658           Vijayan   16             Nadodikkattu         94
# 2       300659           Ramanan   18            Punjabi House         69
# 3       300660     Mannar Mathai   20       Ramji Rao Speaking         93
# 4       300661    Gopalakrishnan   15                Godfather         88
# ..         ...               ...  ...                      ...        ...
# 74      300731            Soumya   21  Maheshinte Prathikaaram         62
# 75      300732            Kannan   21            Minnal Murali         54
# 76      300733           Josemon   21            Minnal Murali         80
# 77      300734             Shibu   19            Minnal Murali         43
# 78      300735  Dashamoolam Damu   21            Chattambinadu         40
#
#     English  Hindi  Social_Science  Physics  Chemistry  Biology  Mathematics  \
# ...

# %%
# Drop row
df.drop(index=0)
# Out:
#     Student_ID              Name  Age                  Address  Malayalam  \
# 1       300658           Vijayan   16             Nadodikkattu         94
# 2       300659           Ramanan   18            Punjabi House         69
# 3       300660     Mannar Mathai   20       Ramji Rao Speaking         93
# 4       300661    Gopalakrishnan   15                Godfather         88
# 5       300662        Appukuttan   21         In Harihar Nagar         77
# ..         ...               ...  ...                      ...        ...
# 74      300731            Soumya   21  Maheshinte Prathikaaram         62
# 75      300732            Kannan   21            Minnal Murali         54
# 76      300733           Josemon   21            Minnal Murali         80
# 77      300734             Shibu   19            Minnal Murali         43
# 78      300735  Dashamoolam Damu   21            Chattambinadu         40
#
#     English  Hindi  Social_Science  Physics  Chemistry  Biology  Mathematics  \
# ...

# %% [markdown]
# # Handling Missing Data
# Missing values are common in real datasets
#     Check missing values.

# %%
# Check missing values
df.isnull()
# Out:
#     Student_ID   Name    Age  Address  Malayalam  English  Hindi  \
# 0        False  False  False    False      False    False  False
# 1        False  False  False    False      False    False  False
# 2        False  False  False    False      False    False  False
# 3        False  False  False    False      False    False  False
# 4        False  False  False    False      False    False  False
# ..         ...    ...    ...      ...        ...      ...    ...
# 74       False  False  False    False      False    False  False
# 75       False  False  False    False      False    False  False
# 76       False  False  False    False      False    False  False
# 77       False  False  False    False      False    False  False
# 78       False  False  False    False      False    False  False
#
#     Social_Science  Physics  Chemistry  Biology  Mathematics  \
# 0            False    False      False    False        False
# ...

# %%
# Drop missing values
df.dropna()
# Out:
#     Student_ID              Name  Age                  Address  Malayalam  \
# 0       300657             Dasan   21             Nadodikkattu         68
# 1       300658           Vijayan   16             Nadodikkattu         94
# 2       300659           Ramanan   18            Punjabi House         69
# 3       300660     Mannar Mathai   20       Ramji Rao Speaking         93
# 4       300661    Gopalakrishnan   15                Godfather         88
# ..         ...               ...  ...                      ...        ...
# 74      300731            Soumya   21  Maheshinte Prathikaaram         62
# 75      300732            Kannan   21            Minnal Murali         54
# 76      300733           Josemon   21            Minnal Murali         80
# 77      300734             Shibu   19            Minnal Murali         43
# 78      300735  Dashamoolam Damu   21            Chattambinadu         40
#
#     English  Hindi  Social_Science  Physics  Chemistry  Biology  Mathematics  \
# ...

# %%
# Fill missing values
df.fillna(0)
# Out:
#     Student_ID              Name  Age                  Address  Malayalam  \
# 0       300657             Dasan   21             Nadodikkattu         68
# 1       300658           Vijayan   16             Nadodikkattu         94
# 2       300659           Ramanan   18            Punjabi House         69
# 3       300660     Mannar Mathai   20       Ramji Rao Speaking         93
# 4       300661    Gopalakrishnan   15                Godfather         88
# ..         ...               ...  ...                      ...        ...
# 74      300731            Soumya   21  Maheshinte Prathikaaram         62
# 75      300732            Kannan   21            Minnal Murali         54
# 76      300733           Josemon   21            Minnal Murali         80
# 77      300734             Shibu   19            Minnal Murali         43
# 78      300735  Dashamoolam Damu   21            Chattambinadu         40
#
#     English  Hindi  Social_Science  Physics  Chemistry  Biology  Mathematics  \
# ...

# %% [markdown]
# ---
#
# # Sorting Data

# %%
# Sort by column
df.sort_values("Age")
# Out:
#     Student_ID                        Name  Age              Address  \
# 4       300661              Gopalakrishnan   15            Godfather
# 15      300672  Adv. Lal Krishna Viradiyar   15            Godfather
# 26      300683                  Thankappan   15        Punjabi House
# 59      300716                        Vasu   15       Kunjiramayanam
# 61      300718                     Babumon   15        Salt N Pepper
# ..         ...                         ...  ...                  ...
# 22      300679     Kottappally Prabhakaran   22            Sandesham
# 19      300676                       Pyari   22         Kalyanaraman
# 51      300708               Pappu Chettan   22                 Aadu
# 65      300722             Kunjappan Robot   22    Android Kunjappan
# 70      300727                        Kora   22  Sudani From Nigeria
#
#     Malayalam  English  Hindi  Social_Science  Physics  Chemistry  Biology  \
# ...

# %%
# Descending
df.sort_values("Age", ascending=False)
# Out:
#     Student_ID                     Name  Age                Address  \
# 46      300703                 Raj Bose   22         Happy Husbands
# 70      300727                     Kora   22    Sudani From Nigeria
# 65      300722          Kunjappan Robot   22      Android Kunjappan
# 51      300708            Pappu Chettan   22                   Aadu
# 22      300679  Kottappally Prabhakaran   22              Sandesham
# ..         ...                      ...  ...                    ...
# 48      300705                 Kunjunni   15  Kilichundan Mampazham
# 50      300707               Velayudhan   15          Chattambinadu
# 59      300716                     Vasu   15         Kunjiramayanam
# 58      300715                  Ambrose   15         Kunjiramayanam
# 68      300725                     Jibi   15              Romancham
#
#     Malayalam  English  Hindi  Social_Science  Physics  Chemistry  Biology  \
# ...

# %% [markdown]
# ---
#
# # Grouping Data (Very Powerful)
#
# Used for aggregation.

# %%
df.groupby("Age")["Malayalam"].mean()
# Out:
# Age
# 15    67.400000
# 16    66.000000
# 17    69.333333
# 18    61.900000
# 19    67.416667
# 20    66.200000
# 21    66.272727
# 22    69.000000
# Name: Malayalam, dtype: float64

# %%
df.groupby("Age").sum()
# Out:
#      Student_ID                                               Name  \
# Age
# 15      3006997  GopalakrishnanAdv. Lal Krishna ViradiyarThanka...
# 16      2405583  VijayanSundaranKunjoonjuMandrakeKunjappuKurish...
# 17      3608281  MahadevanArjunShaji PappanKannan SrankThalathi...
# 18      3006956  RamananThorappan KochunniSankaran KuttyUrumis ...
# 19      3608346  NischalPonnappanAravindanPeethambaranVeerappan...
# 20      3006852  Mannar MathaiGovindan KuttyThomaskuttyPachalam...
# 21      3307754  DasanAppukuttanAdv. GovindanKunjikannanAvarach...
# 22      1804215  PyariKottappally PrabhakaranRaj BosePappu Chet...
#
#                                                Address  Malayalam  English  \
# Age
# 15   GodfatherGodfatherPunjabi HouseThilakkamKilich...        674      635
# 16   NadodikkattuPulival KalyanamEe Parakkum Thalik...        528      464
# 17   In Harihar NagarCID MoosaAaduMayaviVadakkunokk...        832      821
# ...

# %%
df.groupby("Age").count()
# Out:
#      Student_ID  Name  Address  Malayalam  English  Hindi  Social_Science  \
# Age
# 15           10    10       10         10       10     10              10
# 16            8     8        8          8        8      8               8
# 17           12    12       12         12       12     12              12
# 18           10    10       10         10       10     10              10
# 19           12    12       12         12       12     12              12
# 20           10    10       10         10       10     10              10
# 21           11    11       11         11       11     11              11
# 22            6     6        6          6        6      6               6
#
#      Physics  Chemistry  Biology  Mathematics  Information_Technology  Total  \
# Age
# 15        10         10       10           10                      10     10
# 16         8          8        8            8                       8      8
# ...

# %% [markdown]
# ---
#
# # Writing Data
#
# Save processed data.

# %%
# save the modified DataFrame to a new CSV file
out_file_name = r"output.csv"
with open(out_file_name, "w") as f:
    df.to_csv(f, index=False)
